# %%
import shapefile as shp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %%
sns.set(style="whitegrid", palette="pastel", color_codes=True)
sns.mpl.rc("figure", figsize=(10,6))

# %%
sh_path = "./Sector.shp"
sf = shp.Reader(sh_path)
sf.records()[1]
# Out:
# Record #1: [1.0, 'Kigali City', 11.0, 'Nyarugenge', 1102.0, 'Kanyinya']

# %%
sf.records()
# Out:
# [Record #0: [1.0, 'Kigali City', 11.0, 'Nyarugenge', 1101.0, 'Gitega'],
#  Record #1: [1.0, 'Kigali City', 11.0, 'Nyarugenge', 1102.0, 'Kanyinya'],
#  Record #2: [1.0, 'Kigali City', 11.0, 'Nyarugenge', 1103.0, 'Kigali'],
#  Record #3: [1.0, 'Kigali City', 11.0, 'Nyarugenge', 1104.0, 'Kimisagara'],
#  Record #4: [1.0, 'Kigali City', 11.0, 'Nyarugenge', 1105.0, 'Mageregere'],
#  Record #5: [1.0, 'Kigali City', 11.0, 'Nyarugenge', 1106.0, 'Muhima'],
#  Record #6: [1.0, 'Kigali City', 11.0, 'Nyarugenge', 1107.0, 'Nyakabanda'],
#  Record #7: [1.0, 'Kigali City', 11.0, 'Nyarugenge', 1108.0, 'Nyamirambo'],
#  Record #8: [1.0, 'Kigali City', 11.0, 'Nyarugenge', 1109.0, 'Nyarugenge'],
#  Record #9: [1.0, 'Kigali City', 11.0, 'Nyarugenge', 1110.0, 'Rwezamenyo'],
#  Record #10: [1.0, 'Kigali City', 12.0, 'Gasabo', 1201.0, 'Bumbogo'],
#  Record #11: [1.0, 'Kigali City', 12.0, 'Gasabo', 1202.0, 'Gatsata'],
#  Record #12: [1.0, 'Kigali City', 12.0, 'Gasabo', 1203.0, 'Gikomero'],
# ...

# %%
def read_shapefile(sf):
    """
    Read a shapefile into a Pandas dataframe with a 'coords'
    column holding the geometry information. This uses the pyshp
    package
    """
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    shps = [s.points for s in sf.shapes()]
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)
    return df

# %%
df = read_shapefile(sf)
df.shape

# %%
df.sample

# %%
df[df.District == "Rulindo"]

# %%
def plot_shape(id, s=None):
    """ PLOTS A SINGLE SHAPE """
    plt.figure()
    ax = plt.axes()
    ax.set_aspect('equal')
    shape_ex = sf.shape(id)
    x_lon = np.zeros((len(shape_ex.points), 1))
    y_lat = np.zeros((len(shape_ex.points), 1))
    for ip in range(len(shape_ex.points)):
        x_lon[ip] = shape_ex.points[ip][0]
        y_lat[ip] = shape_ex.points[ip][1]
    plt.plot(x_lon, y_lat)
    x0 = np.mean(x_lon)
    y0 = np.mean(y_lat)
    plt.text(x0, y0, s, fontsize=15)
    # use bbox (bounding box) to set plot limits
    plt.xlim(shape_ex.bbox[0], shape_ex.bbox[2])
    return x0, y0

# %%
district = 'Tumba'
dist_id = df[df.Name == district].index[0]
plot_shape(dist_id, district)

# %%
def plot_map_fill(id, sf, x_lim=None,
                  y_lim=None,
                  figsize=(11, 9),
                  color='r'):
    '''
    Plot map with lim coordinates
    '''

    plt.figure(figsize=figsize)
    fig, ax = plt.subplots(figsize=figsize)
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        ax.plot(x, y, 'k')

    shape_ex = sf.shape(id)
    x_lon = np.zeros((len(shape_ex.points), 1))
    y_lat = np.zeros((len(shape_ex.points), 1))
    for ip in range(len(shape_ex.points)):
        x_lon[ip] = shape_ex.points[ip][0]
        y_lat[ip] = shape_ex.points[ip][1]
    ax.fill(x_lon, y_lat, color)

    if (x_lim is not None) & (y_lim is not None):
        plt.xlim(x_lim)
        plt.ylim(y_lim)


plot_map_fill(10, sf, color='c')

# %%
sectors = gpd.read_file("./Sector.shp")

# %%
sectors.plot(legend=True)
# Out:
# <AxesSubplot:>

# %%
sectors.head()
# Out:
#    Prov_ID     Province  Dist_ID    District  Sect_ID        Name  \
# 0      1.0  Kigali City     11.0  Nyarugenge   1101.0      Gitega
# 1      1.0  Kigali City     11.0  Nyarugenge   1102.0    Kanyinya
# 2      1.0  Kigali City     11.0  Nyarugenge   1103.0      Kigali
# 3      1.0  Kigali City     11.0  Nyarugenge   1104.0  Kimisagara
# 4      1.0  Kigali City     11.0  Nyarugenge   1105.0  Mageregere
#
#                                             geometry
# 0  POLYGON ((505371.714 4785311.960, 505376.955 4...
# 1  POLYGON ((498847.140 4793516.119, 498839.366 4...
# 2  POLYGON ((504483.566 4785306.597, 504490.090 4...
# 3  POLYGON ((505001.967 4785564.824, 505007.375 4...
# 4  POLYGON ((505814.263 4778683.386, 505819.771 4...

# %%
sectors.plot(sectors.District == "Nyarugenge", cmap="rainbow")
# Out:
# <AxesSubplot:>
